# %% [markdown]
# # 데이터 불러오기 및 결측치 확인
# train : 2022_09~2023_08
# test : 2023_09, 2023_10, 2023_11

# %%
import pandas as pd
import numpy as np

train_files = ['2022_09.csv', '2022_10.csv', '2022_11.csv', '2022_12.csv', '2023_01.csv', '2023_02.csv',
        '2023_03.csv', '2023_04.csv', '2023_05.csv', '2023_06.csv', '2023_07.csv', '2023_08.csv']

train_df = [pd.read_csv(f) for f in train_files]

train = pd.concat(train_df)
# Out:
# /var/folders/1r/xjj371_x7v7cjx48l_txs48c0000gn/T/ipykernel_18119/1466935718.py:7: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_df = [pd.read_csv(f) for f in train_files]
# /var/folders/1r/xjj371_x7v7cjx48l_txs48c0000gn/T/ipykernel_18119/1466935718.py:7: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_df = [pd.read_csv(f) for f in train_files]
# /var/folders/1r/xjj371_x7v7cjx48l_txs48c0000gn/T/ipykernel_18119/1466935718.py:7: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_df = [pd.read_csv(f) for f in train_files]
# /var/folders/1r/xjj371_x7v7cjx48l_txs48c0000gn/T/ipykernel_18119/1466935718.py:7: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_df = [pd.read_csv(f) for f in train_files]
# /var/folders/1r/xjj371_x7v7cjx48l_txs48c0000gn/T/ipykernel_18119/1466935718.py:7: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_df = [pd.read_csv(f) for f in train_files]
# /var/folders/1r/xjj371_x7v7cjx48l_txs48c0000gn/T/ipykernel_18119/1466935718.py:7: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_df = [pd.read_csv(f) for f in train_files]
# /var/folders/1r/xjj371_x7v7cjx48l_txs48c0000gn/T/ipykernel_18119/1466935718.py:7: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_df = [pd.read_csv(f) for f in train_files]
# /var/folders/1r/xjj371_x7v7cjx48l_txs48c0000gn/T/ipykernel_18119/1466935718.py:7: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_df = [pd.read_csv(f) for f in train_files]
# /var/folders/1r/xjj371_x7v7cjx48l_txs48c0000gn/T/ipykernel_18119/1466935718.py:7: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_df = [pd.read_csv(f) for f in train_files]
# /var/folders/1r/xjj371_x7v7cjx48l_txs48c0000gn/T/ipykernel_18119/1466935718.py:7: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_df = [pd.read_csv(f) for f in train_files]
# /var/folders/1r/xjj371_x7v7cjx48l_txs48c0000gn/T/ipykernel_18119/1466935718.py:7: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_df = [pd.read_csv(f) for f in train_files]
# /var/folders/1r/xjj371_x7v7cjx48l_txs48c0000gn/T/ipykernel_18119/1466935718.py:7: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_df = [pd.read_csv(f) for f in train_files]

# %%
#train 데이터 살펴보기
train.head()
# Out:
#      사용년월 노선번호                    노선명  표준버스정류장ID 버스정류장ARS번호  \
# 0  202209  741      741번(진관차고지~헌인릉입구)  100000001       1001
# 1  202209  470       470번(상암차고지~안골마을)  100000001       1001
# 2  202209  N37  N37번(송파공영차고지~진관공영차고지)  100000001       1001
# 3  202209  N37  N37번(진관공영차고지~송파공영차고지)  100000001       1001
# 4  202209  100         100번(하계동~용산구청)  100000002       1002
#
#                    역명  00시승차총승객수  00시하차총승객수  1시승차총승객수  1시하차총승객수  ...  \
# 0      종로2가사거리(00077)         92         77       105       118  ...
# 1      종로2가사거리(00067)         74         74         3         5  ...
# 2      종로2가사거리(00032)          1          5       287       208  ...
# 3      종로2가사거리(00089)          0          0         0         0  ...
# 4  창경궁.서울대학교병원(00031)          0          0         0         0  ...
#
#    20시하차총승객수  21시승차총승객수  21시하차총승객수  22시승차총승객수  22시하차총승객수  23시승차총승객수  \
# 0        194        263        179        243        163        214
# 1        185        342        169        256        164        231
# 2          0          0          0          0          0          0
# 3          0          0          0          0          0          0
# 4         23         55         36         17         23         27
#
#    23시하차총승객수  교통수단타입코드  교통수단타입명      등록일자
# 0        135        10   서울간선버스  20221003
# 1        131        10   서울간선버스  20221003
# 2          0        51   서울심야버스  20221003
# 3          0        51   서울심야버스  20221003
# 4          5        10   서울간선버스  20221003
#
# [5 rows x 57 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 498176 entries, 0 to 41649
# Data columns (total 57 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   사용년월        498176 non-null  int64
#  1   노선번호        498176 non-null  object
#  2   노선명         498176 non-null  object
#  3   표준버스정류장ID   498176 non-null  int64
#  4   버스정류장ARS번호  498176 non-null  object
#  5   역명          498176 non-null  object
#  6   00시승차총승객수   498176 non-null  int64
#  7   00시하차총승객수   498176 non-null  int64
#  8   1시승차총승객수    498176 non-null  int64
#  9   1시하차총승객수    498176 non-null  int64
#  10  2시승차총승객수    498176 non-null  int64
#  11  2시하차총승객수    498176 non-null  int64
#  12  3시승차총승객수    498176 non-null  int64
#  13  3시하차총승객수    498176 non-null  int64
#  14  4시승차총승객수    498176 non-null  int64
#  15  4시하차총승객수    498176 non-null  int64
#  16  5시승차총승객수    498176 non-null  int64
#  17  5시하차총승객수    498176 non-null  int64
#  18  6시승차총승객수    498176 non-null  int64
#  19  6시하차총승객수    498176 non-null  int64
#  20  7시승차총승객수    498176 non-null  int64
#  21  7시하차총승객수    498176 non-null  int64
#  22  8시승차총승객수    498176 non-null  int64
#  23  8시하차총승객수    498176 non-null  int64
#  24  9시승차총승객수    498176 non-null  int64
#  25  9시하차총승객수    498176 non-null  int64
#  26  10시승차총승객수   498176 non-null  int64
#  27  10시하차총승객수   498176 non-null  int64
#  28  11시승차총승객수   498176 non-null  int64
#  29  11시하차총승객수   498176 non-null  int64
#  30  12시승차총승객수   498176 non-null  int64
#  31  12시하차총승객수   498176 non-null  int64
#  32  13시승차총승객수   498176 non-null  int64
#  33  13시하차총승객수   498176 non-null  int64
#  34  14시승차총승객수   498176 non-null  int64
#  35  14시하차총승객수   498176 non-null  int64
#  36  15시승차총승객수   498176 non-null  int64
#  37  15시하차총승객수   498176 non-null  int64
#  38  16시승차총승객수   498176 non-null  int64
#  39  16시하차총승객수   498176 non-null  int64
#  40  17시승차총승객수   498176 non-null  int64
#  41  17시하차총승객수   498176 non-null  int64
#  42  18시승차총승객수   498176 non-null  int64
#  43  18시하차총승객수   498176 non-null  int64
#  44  19시승차총승객수   498176 non-null  int64
#  45  19시하차총승객수   498176 non-null  int64
#  46  20시승차총승객수   498176 non-null  int64
#  47  20시하차총승객수   498176 non-null  int64
#  48  21시승차총승객수   498176 non-null  int64
#  49  21시하차총승객수   498176 non-null  int64
#  50  22시승차총승객수   498176 non-null  int64
#  51  22시하차총승객수   498176 non-null  int64
#  52  23시승차총승객수   498176 non-null  int64
#  53  23시하차총승객수   498176 non-null  int64
#  54  교통수단타입코드    498176 non-null  int64
#  55  교통수단타입명     498176 non-null  object
#  56  등록일자        498176 non-null  int64
# dtypes: int64(52), object(5)
# memory usage: 220.4+ MB

# %% [markdown]
# 결측치가 없음을 확인할 수 있었다.

# %%
test_files = ['2023_09.csv', '2023_10.csv', '2023_11.csv']

test_df = [pd.read_csv(f) for f in test_files]

test = pd.concat(test_df)
# Out:
# /var/folders/1r/xjj371_x7v7cjx48l_txs48c0000gn/T/ipykernel_18119/36689780.py:3: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   test_df = [pd.read_csv(f) for f in test_files]
# /var/folders/1r/xjj371_x7v7cjx48l_txs48c0000gn/T/ipykernel_18119/36689780.py:3: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   test_df = [pd.read_csv(f) for f in test_files]
# /var/folders/1r/xjj371_x7v7cjx48l_txs48c0000gn/T/ipykernel_18119/36689780.py:3: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   test_df = [pd.read_csv(f) for f in test_files]

# %%
test.head()
# Out:
#      사용년월 노선번호                    노선명  표준버스정류장ID 버스정류장ARS번호  \
# 0  202309  N37  N37번(송파공영차고지~진관공영차고지)  100000001       1001
# 1  202309  470       470번(상암차고지~안골마을)  100000001       1001
# 2  202309  N37  N37번(진관공영차고지~송파공영차고지)  100000001       1001
# 3  202309  741      741번(진관차고지~헌인릉입구)  100000001       1001
# 4  202309  100         100번(하계동~용산구청)  100000002       1002
#
#                    역명  00시승차총승객수  00시하차총승객수  1시승차총승객수  1시하차총승객수  ...  \
# 0      종로2가사거리(00032)         11         18       168       236  ...
# 1      종로2가사거리(00066)         83        109         7         3  ...
# 2      종로2가사거리(00089)          0          0         0         0  ...
# 3      종로2가사거리(00075)        118        122       119       160  ...
# 4  창경궁.서울대학교병원(00031)          0          0         0         0  ...
#
#    20시하차총승객수  21시승차총승객수  21시하차총승객수  22시승차총승객수  22시하차총승객수  23시승차총승객수  \
# 0          0          0          0          0          0          0
# 1        221        419        260        365        246        261
# 2          0          0          0          0          0          0
# 3        279        303        231        227        196        223
# 4         26         77         31         43         42         24
#
#    23시하차총승객수  교통수단타입코드  교통수단타입명      등록일자
# 0          0        51   서울심야버스  20231003
# 1        145        10   서울간선버스  20231003
# 2          0        51   서울심야버스  20231003
# 3        130        10   서울간선버스  20231003
# 4          5        10   서울간선버스  20231003
#
# [5 rows x 57 columns]

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 125576 entries, 0 to 41563
# Data columns (total 57 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   사용년월        125576 non-null  int64
#  1   노선번호        125576 non-null  object
#  2   노선명         125576 non-null  object
#  3   표준버스정류장ID   125576 non-null  int64
#  4   버스정류장ARS번호  125576 non-null  object
#  5   역명          125576 non-null  object
#  6   00시승차총승객수   125576 non-null  int64
#  7   00시하차총승객수   125576 non-null  int64
#  8   1시승차총승객수    125576 non-null  int64
#  9   1시하차총승객수    125576 non-null  int64
#  10  2시승차총승객수    125576 non-null  int64
#  11  2시하차총승객수    125576 non-null  int64
#  12  3시승차총승객수    125576 non-null  int64
#  13  3시하차총승객수    125576 non-null  int64
#  14  4시승차총승객수    125576 non-null  int64
#  15  4시하차총승객수    125576 non-null  int64
#  16  5시승차총승객수    125576 non-null  int64
#  17  5시하차총승객수    125576 non-null  int64
#  18  6시승차총승객수    125576 non-null  int64
#  19  6시하차총승객수    125576 non-null  int64
#  20  7시승차총승객수    125576 non-null  int64
#  21  7시하차총승객수    125576 non-null  int64
#  22  8시승차총승객수    125576 non-null  int64
#  23  8시하차총승객수    125576 non-null  int64
#  24  9시승차총승객수    125576 non-null  int64
#  25  9시하차총승객수    125576 non-null  int64
#  26  10시승차총승객수   125576 non-null  int64
#  27  10시하차총승객수   125576 non-null  int64
#  28  11시승차총승객수   125576 non-null  int64
#  29  11시하차총승객수   125576 non-null  int64
#  30  12시승차총승객수   125576 non-null  int64
#  31  12시하차총승객수   125576 non-null  int64
#  32  13시승차총승객수   125576 non-null  int64
#  33  13시하차총승객수   125576 non-null  int64
#  34  14시승차총승객수   125576 non-null  int64
#  35  14시하차총승객수   125576 non-null  int64
#  36  15시승차총승객수   125576 non-null  int64
#  37  15시하차총승객수   125576 non-null  int64
#  38  16시승차총승객수   125576 non-null  int64
#  39  16시하차총승객수   125576 non-null  int64
#  40  17시승차총승객수   125576 non-null  int64
#  41  17시하차총승객수   125576 non-null  int64
#  42  18시승차총승객수   125576 non-null  int64
#  43  18시하차총승객수   125576 non-null  int64
#  44  19시승차총승객수   125576 non-null  int64
#  45  19시하차총승객수   125576 non-null  int64
#  46  20시승차총승객수   125576 non-null  int64
#  47  20시하차총승객수   125576 non-null  int64
#  48  21시승차총승객수   125576 non-null  int64
#  49  21시하차총승객수   125576 non-null  int64
#  50  22시승차총승객수   125576 non-null  int64
#  51  22시하차총승객수   125576 non-null  int64
#  52  23시승차총승객수   125576 non-null  int64
#  53  23시하차총승객수   125576 non-null  int64
#  54  교통수단타입코드    125576 non-null  int64
#  55  교통수단타입명     125576 non-null  object
#  56  등록일자        125576 non-null  int64
# dtypes: int64(52), object(5)
# memory usage: 55.6+ MB

# %% [markdown]
# ## 칼럼 삭제
# 사용하지 않는 칼럼은 삭제한다.

# %%
train = train.drop(['등록일자', '교통수단타입코드', '버스정류장ARS번호', '표준버스정류장ID', '노선명'], axis=1)

# %%
train.head(3)
# Out:
#      사용년월 노선번호              역명  00시승차총승객수  00시하차총승객수  1시승차총승객수  1시하차총승객수  \
# 0  202209  741  종로2가사거리(00077)         92         77       105       118
# 1  202209  470  종로2가사거리(00067)         74         74         3         5
# 2  202209  N37  종로2가사거리(00032)          1          5       287       208
#
#    2시승차총승객수  2시하차총승객수  3시승차총승객수  ...  19시하차총승객수  20시승차총승객수  20시하차총승객수  \
# 0         0         0         0  ...        389        301        194
# 1         0         0         0  ...        386        327        185
# 2       116        91         0  ...          0          0          0
#
#    21시승차총승객수  21시하차총승객수  22시승차총승객수  22시하차총승객수  23시승차총승객수  23시하차총승객수  교통수단타입명
# 0        263        179        243        163        214        135   서울간선버스
# 1        342        169        256        164        231        131   서울간선버스
# 2          0          0          0          0          0          0   서울심야버스
#
# [3 rows x 52 columns]

# %% [markdown]
# ## 심야버스 삭제
# 출퇴근 시간대를 위주로 분석할 예정이므로 심야버스 row를 삭제한다.
#
# 그리고 인덱스를 새롭게 부여한다.

# %%
train.drop(train[train['교통수단타입명'] == '서울심야버스'].index, inplace=True)

train.reset_index(drop=True, inplace=True)

train.head(3)
# Out:
#      사용년월 노선번호                  역명  00시승차총승객수  00시하차총승객수  1시승차총승객수  1시하차총승객수  \
# 0  202209  100  창경궁.서울대학교병원(00031)          0          0         0         0
# 1  202209  104  창경궁.서울대학교병원(00024)          0          0         0         0
# 2  202209  172  창경궁.서울대학교병원(00028)          0          0         0         0
#
#    2시승차총승객수  2시하차총승객수  3시승차총승객수  ...  19시하차총승객수  20시승차총승객수  20시하차총승객수  \
# 0         0         0         0  ...         60        235         23
# 1         0         0         0  ...         65        194         51
# 2         0         0         0  ...         44        285         36
#
#    21시승차총승객수  21시하차총승객수  22시승차총승객수  22시하차총승객수  23시승차총승객수  23시하차총승객수  교통수단타입명
# 0         55         36         17         23         27          5   서울간선버스
# 1         57         65         28         35         27         20   서울간선버스
# 2         68         28         55         30         47          6   서울간선버스
#
# [3 rows x 52 columns]

# %% [markdown]
# ## 필요없는 시간대 칼럼 삭제, 2시간 단위로 칼럼 재구성
#
# 22시~05시는 제외한다.
#
# 6-8, 8-10, 10-12, 12-14, 14-16, 16-18, 18-20, 20-22로 2시간 단위로 시간대를 묶는다.
#
# X~Y ride(2시간 단위 승차 총 승객 수), X~Y takeoff(2시간 단위 하차 총 승객 수)로 칼럼명을 변경한다.

# %%
train['6~8 ride'] = train['6시승차총승객수'] + train['7시승차총승객수']
train['8~10 ride'] = train['8시승차총승객수'] + train['9시승차총승객수']
train['10~12 ride'] = train['10시승차총승객수'] + train['11시승차총승객수']
train['12~14 ride'] = train['12시승차총승객수'] + train['13시승차총승객수']
train['14~16 ride'] = train['14시승차총승객수'] + train['15시승차총승객수']
train['16~18 ride'] = train['16시승차총승객수'] + train['17시승차총승객수']
train['18~20 ride'] = train['18시승차총승객수'] + train['19시승차총승객수']
train['20~22 ride'] = train['20시승차총승객수'] + train['21시승차총승객수']

time_drop_columns = [f'{hour}시승차총승객수' for hour in range(1,24)]
train.drop(time_drop_columns, axis=1, inplace=True)
train.drop('00시승차총승객수', axis=1, inplace=True)

train['6~8 takeoff'] = train['6시하차총승객수'] + train['7시하차총승객수']
train['8~10 takeoff'] = train['8시하차총승객수'] + train['9시하차총승객수']
train['10~12 takeoff'] = train['10시하차총승객수'] + train['11시하차총승객수']
train['12~14 takeoff'] = train['12시하차총승객수'] + train['13시하차총승객수']
train['14~16 takeoff'] = train['14시하차총승객수'] + train['15시하차총승객수']
train['16~18 takeoff'] = train['16시하차총승객수'] + train['17시하차총승객수']
train['18~20 takeoff'] = train['18시하차총승객수'] + train['19시하차총승객수']
train['20~22 takeoff'] = train['20시하차총승객수'] + train['21시하차총승객수']

time_drop_columns = [f'{hour}시하차총승객수' for hour in range(1,24)]
train.drop(time_drop_columns, axis=1, inplace=True)
train.drop('00시하차총승객수', axis=1, inplace=True)

# %%
train.head()
# Out:
#     month bus_id bus_station_id bus_type  6~8 ride  8~10 ride  10~12 ride  \
# 0  202209    100          00031   서울간선버스       227        677         282
# 1  202209    104          00024   서울간선버스       376        759         381
# 2  202209    172          00028   서울간선버스       285        494         318
# 3  202209    272          00032   서울간선버스       899       1505        1107
# 4  202209    102          00032   서울간선버스       190        324         140
#
#    12~14 ride  14~16 ride  16~18 ride  18~20 ride  20~22 ride  6~8 takeoff  \
# 0         193         381         558         374         290          708
# 1         312         344         464         393         251         1064
# 2         372         494         700         554         353          724
# 3         938        1598        2431        1428         946         1352
# 4         106         151         140         127          34          954
#
#    8~10 takeoff  10~12 takeoff  12~14 takeoff  14~16 takeoff  16~18 takeoff  \
# 0          1114            504            450            353            209
# 1          1765            509            460            451            228
# 2          1195            493            466            359            250
# 3          2358            945            977            958            598
# 4          1673            447            344            256            124
#
#    18~20 takeoff  20~22 takeoff
# 0            146             59
# 1            148            116
# 2            151             64
# 3            440            188
# 4             94             61

# %% [markdown]
# ## 칼럼 이름 재구성
#
# 편의를 위해 칼럼 이름을 영어로 수정한다.
#
# 또한, 역명 칼럼을 괄호 안 5자리 숫자로 대체한다.

# %%
train['역명'] = train['역명'].apply(lambda x: ''.join(filter(str.isdigit, str(x))))

train = train.rename(columns={'사용년월': 'month'})
train = train.rename(columns={'노선번호': 'bus_id'})
train = train.rename(columns={'역명': 'bus_station_id'})
train = train.rename(columns={'교통수단타입명': 'bus_type'})

# %%
train.head(3)
# Out:
#     month bus_id bus_station_id bus_type  6~8 ride  8~10 ride  10~12 ride  \
# 0  202209    100          00031   서울간선버스       227        677         282
# 1  202209    104          00024   서울간선버스       376        759         381
# 2  202209    172          00028   서울간선버스       285        494         318
#
#    12~14 ride  14~16 ride  16~18 ride  18~20 ride  20~22 ride  6~8 takeoff  \
# 0         193         381         558         374         290          708
# 1         312         344         464         393         251         1064
# 2         372         494         700         554         353          724
#
#    8~10 takeoff  10~12 takeoff  12~14 takeoff  14~16 takeoff  16~18 takeoff  \
# 0          1114            504            450            353            209
# 1          1765            509            460            451            228
# 2          1195            493            466            359            250
#
#    18~20 takeoff  20~22 takeoff
# 0            146             59
# 1            148            116
# 2            151             64

# %% [markdown]
# ## 출퇴근 시간 선정
#
# 총 승차 인원(ride)을 기준으로 하여 출퇴근 시간을 선정한다.

# %%
train.describe()
# Out:
#                month       6~8 ride      8~10 ride     10~12 ride  \
# count  188184.000000  188184.000000  188184.000000  188184.000000
# mean   202274.043851     326.123140     472.252981     302.490605
# std        44.052248     485.574969     679.327542     408.592636
# min    202209.000000       0.000000       0.000000       0.000000
# 25%    202212.000000      36.000000      70.000000      51.000000
# 50%    202303.000000     156.000000     256.000000     175.000000
# 75%    202306.000000     419.000000     616.000000     405.000000
# max    202308.000000   14041.000000   33264.000000   23844.000000
#
#           12~14 ride     14~16 ride     16~18 ride     18~20 ride  \
# count  188184.000000  188184.000000  188184.000000  188184.000000
# mean      331.896123     359.097665     455.712255     451.460448
# std       443.218583     496.150776     667.882473     812.560215
# min         0.000000       0.000000       0.000000       0.000000
# 25%        58.000000      64.000000      79.000000      64.000000
# 50%       196.000000     209.000000     256.000000     219.000000
# 75%       443.000000     470.000000     577.000000     520.000000
# max     20184.000000   15493.000000   21949.000000   21116.000000
#
#           20~22 ride    6~8 takeoff   8~10 takeoff  10~12 takeoff  \
# count  188184.000000  188184.000000  188184.000000  188184.000000
# mean      279.988224     257.307996     468.583270     290.718037
# std       569.694905     555.353998     810.020696     445.315409
# min         0.000000       0.000000       0.000000       0.000000
# 25%        32.000000      36.000000      81.000000      56.000000
# 50%       118.000000     109.000000     236.000000     166.000000
# 75%       298.000000     267.000000     542.000000     359.000000
# max     17714.000000   17795.000000   26751.000000   18723.000000
#
#        12~14 takeoff  14~16 takeoff  16~18 takeoff  18~20 takeoff  \
# count  188184.000000  188184.000000  188184.000000  188184.000000
# mean      316.775278     345.993490     439.401634     478.979940
# std       438.106048     444.657216     565.634019     609.661987
# min         0.000000       0.000000       0.000000       0.000000
# 25%        65.000000      73.000000      92.000000      91.000000
# 50%       193.000000     219.000000     278.000000     293.000000
# 75%       409.000000     461.000000     585.000000     643.000000
# max     12885.000000   12451.000000   20034.000000   19740.000000
#
#        20~22 takeoff
# count  188184.000000
# mean      294.140038
# std       391.037489
# min         0.000000
# 25%        50.000000
# 50%       168.000000
# 75%       387.000000
# max     11842.000000

# %%
ride_columns = ['6~8 ride', '8~10 ride', '10~12 ride', 
                '12~14 ride', '14~16 ride', '16~18 ride', '18~20 ride', '20~22 ride']

total_rides = train[ride_columns].sum()

total_rides.head(8)
# Out:
# 6~8 ride      61371157
# 8~10 ride     88870455
# 10~12 ride    56923892
# 12~14 ride    62457540
# 14~16 ride    67576435
# 16~18 ride    85757755
# 18~20 ride    84957633
# 20~22 ride    52689304
# dtype: int64

# %%
import matplotlib.pyplot as plt

# 시간대별 ride 데이터
ride_data = {'6~8 ride': 61371157,
             '8~10 ride': 88870455,
             '10~12 ride': 56923892,
             '12~14 ride': 62457540,
             '14~16 ride': 67576435,
             '16~18 ride': 85757755,
             '18~20 ride': 84957633,
             '20~22 ride': 52689304}

# 막대 그래프 생성
plt.bar(ride_data.keys(), ride_data.values())
# 그래프 제목과 축 레이블 설정
plt.title('Total Rides by Time Period')
plt.xlabel('Time Period')
plt.ylabel('Total Rides')

# 그래프 출력
plt.show()

# %%
takeoff_columns = ['6~8 takeoff', '8~10 takeoff', '10~12 takeoff', 
                '12~14 takeoff', '14~16 takeoff', '16~18 takeoff', '18~20 takeoff', '20~22 takeoff']

total_takeoff = train[takeoff_columns].sum()

total_takeoff.head(8)
# Out:
# 6~8 takeoff      48421248
# 8~10 takeoff     88179874
# 10~12 takeoff    54708483
# 12~14 takeoff    59612039
# 14~16 takeoff    65110439
# 16~18 takeoff    82688357
# 18~20 takeoff    90136361
# 20~22 takeoff    55352449
# dtype: int64

# %%
# takeoff 시간대별 데이터
takeoff_data = {'6~8 takeoff': 71014125,
                '8~10 takeoff': 99724221,
                '10~12 takeoff': 64110750,
                '12~14 takeoff': 68996554,
                '14~16 takeoff': 74333282,
                '16~18 takeoff': 95780136,
                '18~20 takeoff': 95117798,
                '20~22 takeoff': 59638048}

# 막대 그래프 생성
plt.bar(takeoff_data.keys(), takeoff_data.values())

# 그래프 제목과 축 레이블 설정
plt.title('Total Takeoffs by Time Period')
plt.xlabel('Time Period')
plt.ylabel('Total Takeoffs')

# 그래프 출력
plt.show()

# %% [markdown]
# ### 따라서, 출근 시간대를 8~10, 퇴근 시간대를 16~18으로 선정할 수 있음

# %% [markdown]
# ## 정류장별 승하차 인원 시각화

# %%
group_station = train.groupby('bus_station_id').sum().reset_index()

total_by_station_df = group_station[['bus_station_id', '6~8 ride', '8~10 ride', '10~12 ride', '12~14 ride', '14~16 ride', '16~18 ride', '18~20 ride', '20~22 ride',
                                       '6~8 takeoff', '8~10 takeoff', '10~12 takeoff', '12~14 takeoff', '14~16 takeoff', '16~18 takeoff', '18~20 takeoff', '20~22 takeoff']]

total_by_station_df.head()
# Out:
# /var/folders/1r/xjj371_x7v7cjx48l_txs48c0000gn/T/ipykernel_18119/1817796958.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_station = train.groupby('bus_station_id').sum().reset_index()
#   bus_station_id  6~8 ride  8~10 ride  10~12 ride  12~14 ride  14~16 ride  \
# 0          00001   1635015    1986102     1133870     1232573     1297884
# 1          00002   1241686    1610007      888183      914482      952214
# 2          00003   1180059    1507816      828438      834746      816565
# 3          00004   1246095    1565574      946879      971435     1015202
# 4          00005   1193091    1489785      888637      925781      920410
#
#    16~18 ride  18~20 ride  20~22 ride  6~8 takeoff  8~10 takeoff  \
# 0     1638494     1520848      870356       253125        441390
# 1     1204782     1051024      552228        81497        130932
# 2      991758      823354      424291       152042        241777
# 3     1293873     1170633      642183       254986        407422
# 4     1139667      982438      526386       351279        563865
#
#    10~12 takeoff  12~14 takeoff  14~16 takeoff  16~18 takeoff  18~20 takeoff  \
# 0         308064         320478         365257         443652         481050
# 1          80389          86560          96505         123881         140305
# 2         126244         141758         159659         198864         241913
# 3         231451         235322         256145         326915         376011
# 4         301088         311668         338951         439916         484368
#
#    20~22 takeoff
# 0         298998
# 1          77406
# 2         138576
# 3         206333
# 4         275597

# %%
total_by_station_df.describe()
# Out:
#            6~8 ride     8~10 ride    10~12 ride    12~14 ride    14~16 ride  \
# count  2.391000e+03  2.391000e+03  2.391000e+03  2.391000e+03  2.391000e+03
# mean   2.566757e+04  3.716874e+04  2.380757e+04  2.612193e+04  2.826283e+04
# std    1.244909e+05  1.721241e+05  1.092125e+05  1.189892e+05  1.266420e+05
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.250000e+02  4.440000e+02  2.985000e+02  3.335000e+02  3.395000e+02
# 50%    1.369000e+03  2.103000e+03  1.378000e+03  1.496000e+03  1.568000e+03
# 75%    6.023500e+03  8.665500e+03  5.369000e+03  5.683000e+03  6.145000e+03
# max    1.635015e+06  1.986102e+06  1.133870e+06  1.232573e+06  1.297884e+06
#
#          16~18 ride    18~20 ride     20~22 ride    6~8 takeoff  8~10 takeoff  \
# count  2.391000e+03  2.391000e+03    2391.000000    2391.000000  2.391000e+03
# mean   3.586690e+04  3.553226e+04   22036.513593   20251.462986  3.687991e+04
# std    1.590211e+05  1.539033e+05   93919.375084   91367.554138  1.629195e+05
# min    0.000000e+00  0.000000e+00       0.000000       0.000000  0.000000e+00
# 25%    4.290000e+02  3.340000e+02     173.000000     231.500000  5.110000e+02
# 50%    1.965000e+03  1.713000e+03     979.000000     889.000000  1.778000e+03
# 75%    7.644000e+03  7.966500e+03    4856.500000    4028.500000  7.256500e+03
# max    1.638494e+06  1.581793e+06  983971.000000  990877.000000  1.622425e+06
#
#        10~12 takeoff  12~14 takeoff  14~16 takeoff  16~18 takeoff  \
# count    2391.000000    2391.000000   2.391000e+03   2.391000e+03
# mean    22881.005019   24931.843998   2.723147e+04   3.458317e+04
# std     99321.830026  106428.243351   1.141151e+05   1.425349e+05
# min         0.000000       0.000000   0.000000e+00   0.000000e+00
# 25%       393.000000     497.000000   5.720000e+02   7.725000e+02
# 50%      1283.000000    1573.000000   1.890000e+03   2.540000e+03
# 75%      4781.500000    5323.000000   6.112500e+03   7.956500e+03
# max    951589.000000  982827.000000   1.022216e+06   1.258979e+06
#
#        18~20 takeoff  20~22 takeoff
# count   2.391000e+03    2391.000000
# mean    3.769819e+04   23150.334170
# std     1.536731e+05   92570.771235
# min     0.000000e+00       0.000000
# 25%     7.930000e+02     474.500000
# 50%     2.776000e+03    1728.000000
# 75%     8.933000e+03    5556.500000
# max     1.334536e+06  774980.000000

# %%
total_by_station_df['total_ride'] = total_by_station_df[['6~8 ride', '8~10 ride', '10~12 ride', '12~14 ride', '14~16 ride', '16~18 ride', '18~20 ride', '20~22 ride']].sum(axis=1)
total_by_station_df['total_takeoff'] = total_by_station_df[['6~8 takeoff', '8~10 takeoff', '10~12 takeoff', '12~14 takeoff', '14~16 takeoff', '16~18 takeoff', '18~20 takeoff', '20~22 takeoff']].sum(axis=1)

top_3_ride_stations = total_by_station_df.nlargest(3, 'total_ride')[['bus_station_id', 'total_ride']]
top_3_takeoff_stations = total_by_station_df.nlargest(3, 'total_takeoff')[['bus_station_id', 'total_takeoff']]

print("Top 3 Stations by Total Ride")
print(top_3_ride_stations)

print("\nTop 3 Stations by Total Takeoff")
print(top_3_takeoff_stations)
# Out:
# Top 3 Stations by Total Ride
#    bus_station_id  total_ride
# 0           00001    11315142
# 15          00016     9929229
# 14          00015     9587795
#
# Top 3 Stations by Total Takeoff
#    bus_station_id  total_takeoff
# 15          00016        8698458
# 20          00021        8498759
# 17          00018        8207230

# %%
group_station = train.groupby('bus_station_id').sum().reset_index()

fig, ax = plt.subplots(figsize=(12, 6))

group_station.plot(x='bus_station_id', y=['6~8 ride', '8~10 ride', '10~12 ride', '12~14 ride', '14~16 ride', '16~18 ride', '18~20 ride', '20~22 ride'],
                     kind='bar', ax=ax, stacked=True, title='total ride by bus station id')

group_station.plot(x='bus_station_id', y=['6~8 takeoff', '8~10 takeoff', '10~12 takeoff', '12~14 takeoff', '14~16 takeoff', '16~18 takeoff', '18~20 takeoff', '20~22 takeoff'],
                     kind='bar', ax=ax, stacked=True, title='total takeoff by bus station id')

plt.show()
# Out:
# /var/folders/1r/xjj371_x7v7cjx48l_txs48c0000gn/T/ipykernel_18119/24047894.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_station = train.groupby('bus_station_id').sum().reset_index()

# %% [markdown]
# ## Test 데이터프레임 재구성
#
# 기존 대회 형식에 맞춰, test 데이터의 18~20 ride 칼럼을 제거한다.
#
# 또한, train 데이터프레임과 같은 형태로 칼럼을 재구성한다.

# %%
test = test.drop(['등록일자', '교통수단타입코드', '버스정류장ARS번호', '표준버스정류장ID', '노선명'], axis=1)

test.drop(test[test['교통수단타입명'] == '서울심야버스'].index, inplace=True)

test.reset_index(drop=True, inplace=True)

test['6~8 ride'] = test['6시승차총승객수'] + test['7시승차총승객수']
test['8~10 ride'] = test['8시승차총승객수'] + test['9시승차총승객수']
test['10~12 ride'] = test['10시승차총승객수'] + test['11시승차총승객수']
test['12~14 ride'] = test['12시승차총승객수'] + test['13시승차총승객수']
test['14~16 ride'] = test['14시승차총승객수'] + test['15시승차총승객수']
test['16~18 ride'] = test['16시승차총승객수'] + test['17시승차총승객수']
test['18~20 ride'] = test['18시승차총승객수'] + test['19시승차총승객수']
test['20~22 ride'] = test['20시승차총승객수'] + test['21시승차총승객수']

time_drop_columns = [f'{hour}시승차총승객수' for hour in range(1, 24)]
test.drop(time_drop_columns, axis=1, inplace=True)
test.drop('00시승차총승객수', axis=1, inplace=True)

test['6~8 takeoff'] = test['6시하차총승객수'] + test['7시하차총승객수']
test['8~10 takeoff'] = test['8시하차총승객수'] + test['9시하차총승객수']
test['10~12 takeoff'] = test['10시하차총승객수'] + test['11시하차총승객수']
test['12~14 takeoff'] = test['12시하차총승객수'] + test['13시하차총승객수']
test['14~16 takeoff'] = test['14시하차총승객수'] + test['15시하차총승객수']
test['16~18 takeoff'] = test['16시하차총승객수'] + test['17시하차총승객수']
test['18~20 takeoff'] = test['18시하차총승객수'] + test['19시하차총승객수']
test['20~22 takeoff'] = test['20시하차총승객수'] + test['21시하차총승객수']

time_drop_columns = [f'{hour}시하차총승객수' for hour in range(1, 24)]
test.drop(time_drop_columns, axis=1, inplace=True)
test.drop('00시하차총승객수', axis=1, inplace=True)

test['역명'] = test['역명'].apply(lambda x: ''.join(filter(str.isdigit, str(x))))

test = test.rename(columns={'사용년월': 'month'})
test = test.rename(columns={'노선번호': 'bus_id'})
test = test.rename(columns={'역명': 'bus_station_id'})
test = test.rename(columns={'교통수단타입명': 'bus_type'})

# %%
test.drop('18~20 ride', axis=1, inplace=True)

# %%
test.head(3)
# Out:
#     month bus_id bus_station_id bus_type  6~8 ride  8~10 ride  10~12 ride  \
# 0  202309    100          00031   서울간선버스       258        546         313
# 1  202309    104          00024   서울간선버스       295        689         420
# 2  202309    171          00012   서울간선버스       578        911         651
#
#    12~14 ride  14~16 ride  16~18 ride  20~22 ride  6~8 takeoff  8~10 takeoff  \
# 0         256         334         482         229          681           977
# 1         439         452         595         298          953          1377
# 2         518         636         992         437          799          1682
#
#    10~12 takeoff  12~14 takeoff  14~16 takeoff  16~18 takeoff  18~20 takeoff  \
# 0            464            366            358            186            103
# 1            575            471            388            161            138
# 2            417            361            269            241            139
#
#    20~22 takeoff
# 0             57
# 1            107
# 2             69

# %% [markdown]
# ## 독립변수와 종속변수 설정
#
# 18~20 ride를 종속변수로 설정하고, 나머지 다른 칼럼을 독립변수로 설정한다.

# %%
y = train['18~20 ride']
y.head()
# Out:
# 0     374
# 1     393
# 2     554
# 3    1428
# 4     127
# Name: 18~20 ride, dtype: int64

# %%
x = train[['month', 'bus_id', 'bus_station_id', 'bus_type', '6~8 ride', '8~10 ride',
          '10~12 ride', '12~14 ride', '14~16 ride', '16~18 ride', '18~20 ride', '20~22 ride',
          '6~8 takeoff', '8~10 takeoff','10~12 takeoff', '12~14 takeoff', '14~16 takeoff', '16~18 takeoff',
           '18~20 takeoff', '20~22 takeoff']]

x.head()
# Out:
#     month bus_id bus_station_id bus_type  6~8 ride  8~10 ride  10~12 ride  \
# 0  202209    100          00031   서울간선버스       227        677         282
# 1  202209    104          00024   서울간선버스       376        759         381
# 2  202209    172          00028   서울간선버스       285        494         318
# 3  202209    272          00032   서울간선버스       899       1505        1107
# 4  202209    102          00032   서울간선버스       190        324         140
#
#    12~14 ride  14~16 ride  16~18 ride  18~20 ride  20~22 ride  6~8 takeoff  \
# 0         193         381         558         374         290          708
# 1         312         344         464         393         251         1064
# 2         372         494         700         554         353          724
# 3         938        1598        2431        1428         946         1352
# 4         106         151         140         127          34          954
#
#    8~10 takeoff  10~12 takeoff  12~14 takeoff  14~16 takeoff  16~18 takeoff  \
# 0          1114            504            450            353            209
# 1          1765            509            460            451            228
# 2          1195            493            466            359            250
# 3          2358            945            977            958            598
# 4          1673            447            344            256            124
#
#    18~20 takeoff  20~22 takeoff
# 0            146             59
# 1            148            116
# 2            151             64
# 3            440            188
# 4             94             61

# %% [markdown]
# ### 날씨 데이터 추가

# %%
temperature_df = pd.read_csv('2022_2023_기온.csv')

temperature_df = temperature_df.drop(temperature_df.index[24:])

temperature_df
# Out:
#    \t\t지점번호 지점명      일시  평균기온(℃)  평균최고기온(℃)  최고기온(℃)    \t최고기온일자  평균최저기온(℃)  \
# 0   \t\t108  서울  Jan.22     -2.2        2.6      8.4   2022.1.24       -6.2
# 1   \t\t108  서울  Feb.22     -1.1        3.8     11.5   2022.2.28       -5.3
# 2   \t\t108  서울  Mar.22      7.7       12.7     19.5   2022.3.12        3.2
# 3   \t\t108  서울  Apr.22     14.8       20.6     28.7   2022.4.26       10.0
# 4   \t\t108  서울  May.22     19.1       25.0     30.7   2022.5.23       13.9
# 5   \t\t108  서울  Jun.22     23.3       27.5     32.7   2022.6.11       19.8
# 6   \t\t108  서울  Jul.22     27.3       31.0     36.1   2022.7.30       24.2
# 7   \t\t108  서울  Aug.22     25.7       28.9     32.9    2022.8.4       23.1
# 8   \t\t108  서울  Sep.22     22.4       27.2     32.5   2022.9.18       18.2
# 9   \t\t108  서울  Oct.22     14.6       19.7     27.6   2022.10.1       10.3
# 10  \t\t108  서울  Nov.22     10.0       15.4     22.1  2022.11.11        5.6
# 11  \t\t108  서울  Dec.22     -2.8        1.7     10.2   2022.12.9       -6.6
# 12  \t\t108  서울  Jan.23     -1.5        3.2     12.5   2023.1.12       -5.7
# 13  \t\t108  서울  Feb.23      2.3        7.3     12.4   2023.2.27       -1.9
# 14  \t\t108  서울  Mar.23      9.8       16.2     25.1   2023.3.22        4.2
# 15  \t\t108  서울  Apr.23     13.8       19.0     28.4   2023.4.19        8.8
# 16  \t\t108  서울  May.23     19.5       25.0     31.2   2023.5.16       14.6
# 17  \t\t108  서울  Jun.23     23.4       27.9     34.0   2023.6.19       19.7
# 18  \t\t108  서울  Jul.23     26.7       30.2     34.9   2023.7.30       23.9
# 19  \t\t108  서울  Aug.23     27.2       30.8     35.8    2023.8.8       24.3
# 20  \t\t108  서울  Sep.23     23.7       27.6     32.8    2023.9.5       20.2
# 21  \t\t108  서울  Oct.23     15.8       21.0     24.6   2023.10.2       11.5
# 22  \t\t108  서울  Nov.23      6.8       11.5     25.9   2023.11.2        2.9
# 23  \t\t108  서울  Dec.23      1.1        5.2     16.8   2023.12.8       -2.5
#
#     최저기온(℃)      최저기온일자
# 0     -11.3   2022.1.12
# 1     -10.7   2022.2.17
# 2      -3.0    2022.3.6
# 3       3.5    2022.4.3
# 4       7.9    2022.5.1
# 5      14.9   2022.6.15
# 6      20.8   2022.7.21
# 7      16.1   2022.8.28
# 8      12.3   2022.9.24
# 9       4.4  2022.10.19
# 10     -8.1  2022.11.30
# 11    -13.7  2022.12.23
# 12    -17.3   2023.1.25
# 13     -5.3   2023.2.21
# 14     -1.9   2023.3.13
# 15      3.1    2023.4.8
# 16      7.9    2023.5.8
# 17     16.6    2023.6.3
# 18     21.6   2023.7.11
# 19     20.8   2023.8.28
# 20     15.2   2023.9.22
# 21      5.4  2023.10.22
# 22     -7.3  2023.11.30
# 23    -14.7  2023.12.22

# %%
precipitation_df = pd.read_csv('2022_2023_강수량.csv')

precipitation_df = precipitation_df.drop(precipitation_df.index[24:])

precipitation_df
# Out:
#    \t지점번호 지점명      일시  강수량(mm)  일최다강수량(mm)    일최다강수량일자  1시간최다강수량(mm)  \
# 0   \t108  서울  Jan.22      5.5         1.7   2022.1.19           NaN
# 1   \t108  서울  Feb.22      4.7         1.7   2022.2.14           NaN
# 2   \t108  서울  Mar.22    102.6        42.1   2022.3.13           NaN
# 3   \t108  서울  Apr.22     20.4        15.5   2022.4.29           4.0
# 4   \t108  서울  May.22      7.5         3.5   2022.5.25           2.9
# 5   \t108  서울  Jun.22    393.8       176.2   2022.6.30          34.4
# 6   \t108  서울  Jul.22    252.3       114.5   2022.7.13          33.8
# 7   \t108  서울  Aug.22    564.8       129.6    2022.8.8          47.1
# 8   \t108  서울  Sep.22    201.5       120.0    2022.9.5          12.8
# 9   \t108  서울  Oct.22    124.1        76.0   2022.10.3          14.7
# 10  \t108  서울  Nov.22     84.5        57.9  2022.11.12           NaN
# 11  \t108  서울  Dec.22     13.6         5.4  2022.12.12           NaN
# 12  \t108  서울  Jan.23     47.9        37.3   2023.1.13           NaN
# 13  \t108  서울  Feb.23      1.0         0.6   2023.2.10           NaN
# 14  \t108  서울  Mar.23     10.5         5.6   2023.3.12           NaN
# 15  \t108  서울  Apr.23     96.9        50.3    2023.4.5           9.0
# 16  \t108  서울  May.23    155.6        47.5    2023.5.6           9.3
# 17  \t108  서울  Jun.23    195.6        63.8   2023.6.29          33.8
# 18  \t108  서울  Jul.23    459.9        91.6   2023.7.13          35.0
# 19  \t108  서울  Aug.23    298.1        86.1   2023.8.10          29.0
# 20  \t108  서울  Sep.23    134.5        38.7   2023.9.16          28.0
# 21  \t108  서울  Oct.23     31.0        14.7   2023.10.4          11.7
# 22  \t108  서울  Nov.23     81.9        45.8   2023.11.6           NaN
# 23  \t108  서울  Dec.23     85.9        31.1  2023.12.15           NaN
#
#    1시간최다강수량일자
# 0         NaN
# 1         NaN
# 2         NaN
# 3   2022.4.29
# 4   2022.5.25
# 5   2022.6.23
# 6   2022.7.16
# 7   2022.8.19
# 8    2022.9.5
# 9   2022.10.3
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15   2023.4.5
# 16   2023.5.6
# 17  2023.6.29
# 18  2023.7.13
# 19  2023.8.22
# 20  2023.9.16
# 21  2023.10.4
# 22        NaN
# 23        NaN

# %% [markdown]
# ## 날씨와 승하차인원 사이의 상관관계 분석
#
# 기온, 강수량 데이터와 승하차인원 데이터 사이의 상관관계가 있는지 분석한다.

# %%
#월별 승차 인원 합
monthly_total_rides = train.groupby('month')[['6~8 ride', '8~10 ride', '10~12 ride', '12~14 ride',
                                              '14~16 ride', '16~18 ride', '18~20 ride', '20~22 ride']].sum()

monthly_total_rides.head()

monthly_total_rides['total_ride'] = monthly_total_rides.sum(axis=1)

monthly_total_rides.head()
# Out:
#         6~8 ride  8~10 ride  10~12 ride  12~14 ride  14~16 ride  16~18 ride  \
# month
# 202209   4980514    7182164     4547261     5024142     5561083     7177238
# 202210   4904758    7275131     4822151     5298983     5717843     7230330
# 202211   5165538    7765456     4735396     5195795     5695239     7390506
# 202212   5113856    7704045     4929132     5418928     5978439     7388463
# 202301   4301618    6734804     4334794     4942387     5221120     6344037
#
#         18~20 ride  20~22 ride  total_ride
# month
# 202209     7075417     4327273    45875092
# 202210     6990436     4356836    46596468
# 202211     7245206     4390093    47583229
# 202212     7081877     4385858    48000598
# 202301     6648363     4017543    42544666
